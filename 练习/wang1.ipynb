# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1;WOW64) AppleWebKit/537.36(KHTML,like Geko)Chrome/56.0.2924.87 Safari/537.36'}

# %%
def get_info(url):
    wb_data=requests.get(url,headers=headers)
    soup=BeautifulSoup(wb_data.text,'lxml')
    ranks=soup.select('span.pc_temp_num')
    titles=soup.select('div.pc_temp_songlist > ul> li> a')
    times=soup.select('span.pc_temp_tips_r > span')
    for rank,title,time in zip(ranks,titles,times):
        data={
            'rank':rank.get_text().strip(),
            'singer':title.get_text().split('-')[1],
            'song':title.get_text().split('-')[0],
            'time':time.get_text().strip()
        }
        print(data)

# %%
if __name__ == '__main__':
   urls=['http://www.kugou.com/yy/rank/home/{}-8888.html'.format(str(i)) for i in range(1,24)]
   for url in urls:
       get_info(url)
       time.sleep(1)
# Out:
# {'rank': '1', 'singer': ' 言瑾羽\n', 'song': '\n\t\t\t\t\t\t\t\t\t未必\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:13'}
# {'rank': '2', 'singer': ' 陈冠希、MC仁、厨房仔、应采儿\n', 'song': '\n\t\t\t\t\t\t\t\t\tEverywhere We Go\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:19'}
# {'rank': '3', 'singer': ' 毛不易\n', 'song': '\n\t\t\t\t\t\t\t\t\t无名的人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:42'}
# {'rank': '4', 'singer': ' 周深\n', 'song': '\n\t\t\t\t\t\t\t\t\t小美满\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:34'}
# {'rank': '5', 'singer': ' 就是南方凯\n', 'song': '\n\t\t\t\t\t\t\t\t\t离别开出花 (弹唱版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:52'}
# {'rank': '6', 'singer': ' 张韶涵\n', 'song': '\n\t\t\t\t\t\t\t\t\t有形的翅膀\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:36'}
# {'rank': '7', 'singer': ' 徐靖雯、王忻辰\n', 'song': '\n\t\t\t\t\t\t\t\t\t我的心下起了雪\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:15'}
# {'rank': '8', 'singer': ' 王宇宙Leto、乔浚丞\n', 'song': '\n\t\t\t\t\t\t\t\t\t若月亮没来 (若是月亮还没来)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:53'}
# {'rank': '9', 'singer': ' 汪苏泷、单依纯\n', 'song': '\n\t\t\t\t\t\t\t\t\t如果爱忘了 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:05'}
# {'rank': '10', 'singer': ' 闪闪、唐宁\n', 'song': '\n\t\t\t\t\t\t\t\t\t神奇阿呦（阿呦阿呦+我和你）\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:59'}
# {'rank': '11', 'singer': ' 徐佳莹\n', 'song': '\n\t\t\t\t\t\t\t\t\t身骑白马\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:13'}
# {'rank': '12', 'singer': ' 邹沛沛、Pank\n', 'song': '\n\t\t\t\t\t\t\t\t\t沉溺 (你让我的心不再结冰)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:13'}
# {'rank': '13', 'singer': ' Chester Young、Rave Republic、Kris Kiss\n', 'song': '\n\t\t\t\t\t\t\t\t\tRepeat\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:05'}
# {'rank': '14', 'singer': ' 孙楠、陈楚生\n', 'song': '\n\t\t\t\t\t\t\t\t\t无名的人 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:20'}
# {'rank': '15', 'singer': ' ADAM\n', 'song': '\n\t\t\t\t\t\t\t\t\tZhurek\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:16'}
# {'rank': '16', 'singer': ' 杜宣达\n', 'song': '\n\t\t\t\t\t\t\t\t\t指纹\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '17', 'singer': ' 家家\n', 'song': '\n\t\t\t\t\t\t\t\t\t命运\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:50'}
# {'rank': '18', 'singer': ' 巴扎黑\n', 'song': '\n\t\t\t\t\t\t\t\t\t春风何时来\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:25'}
# {'rank': '19', 'singer': ' 邹沛沛\n', 'song': '\n\t\t\t\t\t\t\t\t\t梦臆\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '20', 'singer': ' 渔总up\n', 'song': '\n\t\t\t\t\t\t\t\t\t你走 (女版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:28'}
# {'rank': '21', 'singer': ' 汪苏泷\n', 'song': '\n\t\t\t\t\t\t\t\t\t我想念\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:44'}
# {'rank': '22', 'singer': ' 韦礼安\n', 'song': '\n\t\t\t\t\t\t\t\t\t如果可以\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:34'}
# {'rank': '23', 'singer': ' 邵帅\n', 'song': '\n\t\t\t\t\t\t\t\t\t南风北巷\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:07'}
# {'rank': '24', 'singer': ' 宇西\n', 'song': '\n\t\t\t\t\t\t\t\t\t安和桥\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '25', 'singer': ' 何洁\n', 'song': '\n\t\t\t\t\t\t\t\t\t你是我的风景\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '26', 'singer': ' Taylor Swift\n', 'song': '\n\t\t\t\t\t\t\t\t\tCruel Summer\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:58'}
# {'rank': '27', 'singer': ' 毛不易\n', 'song': '\n\t\t\t\t\t\t\t\t\t一程山路\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:35'}
# {'rank': '28', 'singer': ' 海来阿木、单依纯\n', 'song': '\n\t\t\t\t\t\t\t\t\t不如见一面\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:40'}
# {'rank': '29', 'singer': ' Taylor Swift\n', 'song': '\n\t\t\t\t\t\t\t\t\tLove Story\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:56'}
# {'rank': '30', 'singer': ' 张妙格\n', 'song': '\n\t\t\t\t\t\t\t\t\t我期待的不是雪 (而是有你的冬天)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:46'}
# {'rank': '31', 'singer': ' L1NO、Fatrik\n', 'song': '\n\t\t\t\t\t\t\t\t\t窒 Suffocating\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:14'}
# {'rank': '32', 'singer': ' 曲婉婷\n', 'song': '\n\t\t\t\t\t\t\t\t\t最好的安排\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '33', 'singer': ' 吴半首\n', 'song': '\n\t\t\t\t\t\t\t\t\t你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:02'}
# {'rank': '34', 'singer': ' JYJ\n', 'song': '\n\t\t\t\t\t\t\t\t\tBack Seat\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:10'}
# {'rank': '35', 'singer': ' 云汐\n', 'song': '\n\t\t\t\t\t\t\t\t\t命运\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:05'}
# {'rank': '36', 'singer': ' 柯柯柯啊\n', 'song': '\n\t\t\t\t\t\t\t\t\t姑娘别哭泣 (弹唱版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '37', 'singer': ' 葛东琪\n', 'song': '\n\t\t\t\t\t\t\t\t\t悬溺\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:17'}
# {'rank': '38', 'singer': ' 郭顶\n', 'song': '\n\t\t\t\t\t\t\t\t\t凄美地\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '39', 'singer': ' 郑润泽\n', 'song': '\n\t\t\t\t\t\t\t\t\t瞬\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:44'}
# {'rank': '40', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t句号\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:55'}
# {'rank': '41', 'singer': ' 抠抠\n', 'song': '\n\t\t\t\t\t\t\t\t\t哎呦我的姑娘\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:14'}
# {'rank': '42', 'singer': ' 熊大、熊二、光头强\n', 'song': '\n\t\t\t\t\t\t\t\t\t再次与你同行\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '43', 'singer': ' Jordann\n', 'song': '\n\t\t\t\t\t\t\t\t\tDehors (外面)(Single Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:15'}
# {'rank': '44', 'singer': ' 海来阿木\n', 'song': '\n\t\t\t\t\t\t\t\t\t不如见一面\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:07'}
# {'rank': '45', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t红尘客栈\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:34'}
# {'rank': '46', 'singer': ' Alexandra Stan、Manilla Maniacs\n', 'song': '\n\t\t\t\t\t\t\t\t\tAll My People\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:19'}
# {'rank': '47', 'singer': ' 黄晓明、刘涛、周杰、古巨基、马伊琍、黄奕\n', 'song': '\n\t\t\t\t\t\t\t\t\t只要有你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:17'}
# {'rank': '48', 'singer': ' Tanir、Tyomcha\n', 'song': '\n\t\t\t\t\t\t\t\t\tDa Da Da (Remix by Mikis)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:03'}
# {'rank': '49', 'singer': ' 曲肖冰\n', 'song': '\n\t\t\t\t\t\t\t\t\t谁\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:37'}
# {'rank': '50', 'singer': ' 梁博\n', 'song': '\n\t\t\t\t\t\t\t\t\t出现又离开 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '6:56'}
# {'rank': '51', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t我还想她\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:07'}
# {'rank': '52', 'singer': ' 弹棉花的小花\n', 'song': '\n\t\t\t\t\t\t\t\t\t无名的人 (女版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:19'}
# {'rank': '53', 'singer': ' 丁当\n', 'song': '\n\t\t\t\t\t\t\t\t\t猜不透\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:53'}
# {'rank': '54', 'singer': ' 张叶蕾\n', 'song': '\n\t\t\t\t\t\t\t\t\t还是分开\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:49'}
# {'rank': '55', 'singer': ' 陈粒\n', 'song': '\n\t\t\t\t\t\t\t\t\t虚拟\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '56', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t晴天\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:29'}
# {'rank': '57', 'singer': ' 汪苏泷\n', 'song': '\n\t\t\t\t\t\t\t\t\t雨天\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:34'}
# {'rank': '58', 'singer': ' 薛之谦\n', 'song': '\n\t\t\t\t\t\t\t\t\t意外\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:51'}
# {'rank': '59', 'singer': ' 杨乃文\n', 'song': '\n\t\t\t\t\t\t\t\t\t推开世界的门\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:42'}
# {'rank': '60', 'singer': ' 任夏\n', 'song': '\n\t\t\t\t\t\t\t\t\t你总要学会往前走\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:07'}
# {'rank': '61', 'singer': ' Cafuné\n', 'song': '\n\t\t\t\t\t\t\t\t\tTek It (Sped Up)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:46'}
# {'rank': '62', 'singer': ' 海来阿木\n', 'song': '\n\t\t\t\t\t\t\t\t\t西楼儿女\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '63', 'singer': ' 我是土豆\n', 'song': '\n\t\t\t\t\t\t\t\t\t放 (加速版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:20'}
# {'rank': '64', 'singer': ' 方大同\n', 'song': '\n\t\t\t\t\t\t\t\t\t特别的人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:19'}
# {'rank': '65', 'singer': ' 海来阿木\n', 'song': '\n\t\t\t\t\t\t\t\t\t你的万水千山\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '66', 'singer': ' Hit The Button Karaoke\n', 'song': '\n\t\t\t\t\t\t\t\t\tRed Moon (Originally Performed by Lil Uzi Vert)(Karaoke Instrumental Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:50'}
# {'rank': '67', 'singer': ' Hi Noise\n', 'song': '\n\t\t\t\t\t\t\t\t\tWe Never\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '68', 'singer': ' 郭采洁\n', 'song': '\n\t\t\t\t\t\t\t\t\t你在，不在\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:23'}
# {'rank': '69', 'singer': ' 蔡健雅\n', 'song': '\n\t\t\t\t\t\t\t\t\t红色高跟鞋\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:26'}
# {'rank': '70', 'singer': ' 阿肆\n', 'song': '\n\t\t\t\t\t\t\t\t\t直到你降临\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:39'}
# {'rank': '71', 'singer': ' 刘人语\n', 'song': '\n\t\t\t\t\t\t\t\t\t心跳的证明\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:50'}
# {'rank': '72', 'singer': ' 任素汐\n', 'song': '\n\t\t\t\t\t\t\t\t\t枕着光的她\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:10'}
# {'rank': '73', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t慢冷 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:44'}
# {'rank': '74', 'singer': ' 林三七\n', 'song': '\n\t\t\t\t\t\t\t\t\t野草与栀子花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:26'}
# {'rank': '75', 'singer': ' 颜人中\n', 'song': '\n\t\t\t\t\t\t\t\t\t夏夜最后的烟火\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:39'}
# {'rank': '76', 'singer': ' GooGoo、王之睿\n', 'song': '\n\t\t\t\t\t\t\t\t\t我的纸飞机\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:16'}
# {'rank': '77', 'singer': ' 向思思\n', 'song': '\n\t\t\t\t\t\t\t\t\t我为你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:46'}
# {'rank': '78', 'singer': ' 江语晨\n', 'song': '\n\t\t\t\t\t\t\t\t\t最后一页\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:05'}
# {'rank': '79', 'singer': ' 薛之谦\n', 'song': '\n\t\t\t\t\t\t\t\t\t野心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:40'}
# {'rank': '80', 'singer': ' 侯泽润\n', 'song': '\n\t\t\t\t\t\t\t\t\t我把故事酿成酒\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:51'}
# {'rank': '81', 'singer': ' 邵帅\n', 'song': '\n\t\t\t\t\t\t\t\t\t暖一杯茶\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:03'}
# {'rank': '82', 'singer': ' 张学友\n', 'song': '\n\t\t\t\t\t\t\t\t\t偷心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:21'}
# {'rank': '83', 'singer': ' Eric周兴哲\n', 'song': '\n\t\t\t\t\t\t\t\t\t你,好不好?\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:47'}
# {'rank': '84', 'singer': ' Krista Marina、Arc North\n', 'song': '\n\t\t\t\t\t\t\t\t\tMeant to Be\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:28'}
# {'rank': '85', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t反方向的钟\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:18'}
# {'rank': '86', 'singer': ' 盛哲\n', 'song': '\n\t\t\t\t\t\t\t\t\t在你的身边\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:22'}
# {'rank': '87', 'singer': ' 弹棉花的小花\n', 'song': '\n\t\t\t\t\t\t\t\t\t身骑白马（而你却靠近了）\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '88', 'singer': ' 野哥\n', 'song': '\n\t\t\t\t\t\t\t\t\t哎呦我的姑娘\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:14'}
# {'rank': '89', 'singer': ' Cody Fry、Abby Cates\n', 'song': '\n\t\t\t\t\t\t\t\t\tThings You Said\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '90', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t不遗憾\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:20'}
# {'rank': '91', 'singer': ' 浩然H.R\n', 'song': '\n\t\t\t\t\t\t\t\t\t年少的你啊\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:00'}
# {'rank': '92', 'singer': ' Hillsong Young & Free\n', 'song': '\n\t\t\t\t\t\t\t\t\tWake (Studio)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:14'}
# {'rank': '93', 'singer': ' 买辣椒也用券\n', 'song': '\n\t\t\t\t\t\t\t\t\t起风了\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:25'}
# {'rank': '94', 'singer': ' Wiz Khalifa、Charlie Puth\n', 'song': '\n\t\t\t\t\t\t\t\t\tSee You Again\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:49'}
# {'rank': '95', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t一路向北\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:55'}
# {'rank': '96', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t多远都要在一起\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:37'}
# {'rank': '97', 'singer': ' Lil Yo\n', 'song': '\n\t\t\t\t\t\t\t\t\t左肩 (你把右手放在我左肩)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:16'}
# {'rank': '98', 'singer': ' 赵雷\n', 'song': '\n\t\t\t\t\t\t\t\t\t我记得\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:29'}
# {'rank': '99', 'singer': ' 王蓉\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱情慢慢摇 (女生版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:25'}
# {'rank': '100', 'singer': ' Big Cole\n', 'song': '\n\t\t\t\t\t\t\t\t\t热烈的少年\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:06'}
# {'rank': '101', 'singer': ' 周深\n', 'song': '\n\t\t\t\t\t\t\t\t\t门\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:24'}
# {'rank': '102', 'singer': ' 陈墨一（吖毛）\n', 'song': '\n\t\t\t\t\t\t\t\t\t回不去的何止时间\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:40'}
# {'rank': '103', 'singer': ' 于冬然\n', 'song': '\n\t\t\t\t\t\t\t\t\t其实都没有\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:42'}
# {'rank': '104', 'singer': ' 单依纯\n', 'song': '\n\t\t\t\t\t\t\t\t\t想你时风起\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:36'}
# {'rank': '105', 'singer': ' BEYOND\n', 'song': '\n\t\t\t\t\t\t\t\t\t海阔天空\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:24'}
# {'rank': '106', 'singer': ' 街道办GDC、欧阳耀莹\n', 'song': '\n\t\t\t\t\t\t\t\t\t春娇与志明\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:25'}
# {'rank': '107', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t喜欢你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '108', 'singer': ' 杨丞琳\n', 'song': '\n\t\t\t\t\t\t\t\t\t带我走\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:51'}
# {'rank': '109', 'singer': ' 侯泽润\n', 'song': '\n\t\t\t\t\t\t\t\t\t大风吹倒梧桐树\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:21'}
# {'rank': '110', 'singer': ' 福禄寿FloruitShow\n', 'song': '\n\t\t\t\t\t\t\t\t\t我用什么把你留住 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:51'}
# {'rank': '111', 'singer': ' 李玉刚\n', 'song': '\n\t\t\t\t\t\t\t\t\t刚好遇见你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:20'}
# {'rank': '112', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t青花瓷\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '113', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t不将就\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:13'}
# {'rank': '114', 'singer': ' Måneskin\n', 'song': '\n\t\t\t\t\t\t\t\t\tI WANNA BE YOUR SLAVE (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:53'}
# {'rank': '115', 'singer': ' BEYOND\n', 'song': '\n\t\t\t\t\t\t\t\t\t光辉岁月\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:02'}
# {'rank': '116', 'singer': ' 张芸京\n', 'song': '\n\t\t\t\t\t\t\t\t\t偏爱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:32'}
# {'rank': '117', 'singer': ' 王菲\n', 'song': '\n\t\t\t\t\t\t\t\t\t如愿\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:25'}
# {'rank': '118', 'singer': ' en\n', 'song': '\n\t\t\t\t\t\t\t\t\t错的人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:16'}
# {'rank': '119', 'singer': ' 唐宁\n', 'song': '\n\t\t\t\t\t\t\t\t\t我和你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '1:25'}
# {'rank': '120', 'singer': ' 抠抠\n', 'song': '\n\t\t\t\t\t\t\t\t\t星光就在前方\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:58'}
# {'rank': '121', 'singer': ' 杨丞琳\n', 'song': '\n\t\t\t\t\t\t\t\t\t雨爱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '122', 'singer': ' 蔡健雅\n', 'song': '\n\t\t\t\t\t\t\t\t\t越来越不懂\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '123', 'singer': ' 苏星婕\n', 'song': '\n\t\t\t\t\t\t\t\t\t把回忆拼好给你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:01'}
# {'rank': '124', 'singer': ' 张靓颖、王赫野\n', 'song': '\n\t\t\t\t\t\t\t\t\t是你 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '125', 'singer': ' 七元\n', 'song': '\n\t\t\t\t\t\t\t\t\tSomeone You Loved\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:02'}
# {'rank': '126', 'singer': ' 锤娜丽莎\n', 'song': '\n\t\t\t\t\t\t\t\t\t我太笨\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:24'}
# {'rank': '127', 'singer': ' Kelly Clarkson\n', 'song': '\n\t\t\t\t\t\t\t\t\tCatch My Breath\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '128', 'singer': ' 欧阳耀莹\n', 'song': '\n\t\t\t\t\t\t\t\t\t戒不掉\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:06'}
# {'rank': '129', 'singer': ' 于冬然\n', 'song': '\n\t\t\t\t\t\t\t\t\t听说你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '130', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t兰亭序\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:13'}
# {'rank': '131', 'singer': ' 是周周\n', 'song': '\n\t\t\t\t\t\t\t\t\t紫荆花盛开\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:33'}
# {'rank': '132', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t烟花易冷\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:23'}
# {'rank': '133', 'singer': ' 小咪\n', 'song': '\n\t\t\t\t\t\t\t\t\t我走后\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '134', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t退后\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:21'}
# {'rank': '135', 'singer': ' 张紫豪\n', 'song': '\n\t\t\t\t\t\t\t\t\t可不可以\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '136', 'singer': ' DAISHI DANCE、Cécile Corbel\n', 'song': '\n\t\t\t\t\t\t\t\t\tTake Me Hand\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '137', 'singer': ' 承桓\n', 'song': '\n\t\t\t\t\t\t\t\t\t我会等\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:15'}
# {'rank': '138', 'singer': ' 张杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t天下\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:41'}
# {'rank': '139', 'singer': ' 阿桑\n', 'song': '\n\t\t\t\t\t\t\t\t\t一直很安静\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '140', 'singer': ' 夏天Alex\n', 'song': '\n\t\t\t\t\t\t\t\t\t等我先说\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:29'}
# {'rank': '141', 'singer': ' 赵浩宇\n', 'song': '\n\t\t\t\t\t\t\t\t\t春风何时来 (释怀版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:31'}
# {'rank': '142', 'singer': ' 闪闪\n', 'song': '\n\t\t\t\t\t\t\t\t\t阿呦阿呦\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '1:34'}
# {'rank': '143', 'singer': ' 丁世光\n', 'song': '\n\t\t\t\t\t\t\t\t\t瘦子 (Skinny Love)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:46'}
# {'rank': '144', 'singer': ' Athletics\n', 'song': '\n\t\t\t\t\t\t\t\t\tIII\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '6:10'}
# {'rank': '145', 'singer': ' 蔡健雅\n', 'song': '\n\t\t\t\t\t\t\t\t\tLetting Go\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:23'}
# {'rank': '146', 'singer': ' 曲婉婷\n', 'song': '\n\t\t\t\t\t\t\t\t\tJar Of Love (Album Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:50'}
# {'rank': '147', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t七里香\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:59'}
# {'rank': '148', 'singer': ' BEYOND\n', 'song': '\n\t\t\t\t\t\t\t\t\t真的爱你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:35'}
# {'rank': '149', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t倒数\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:49'}
# {'rank': '150', 'singer': ' 侯泽润\n', 'song': '\n\t\t\t\t\t\t\t\t\t一句先苦后甜\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:26'}
# {'rank': '151', 'singer': ' 魏晨、魏大勋、白敬亭\n', 'song': '\n\t\t\t\t\t\t\t\t\t歌曲：上春山 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:31'}
# {'rank': '152', 'singer': ' 方大同\n', 'song': '\n\t\t\t\t\t\t\t\t\t麦恩莉\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:48'}
# {'rank': '153', 'singer': ' Justin Bieber、Ludacris\n', 'song': '\n\t\t\t\t\t\t\t\t\tBaby\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:36'}
# {'rank': '154', 'singer': ' 指尖笑\n', 'song': '\n\t\t\t\t\t\t\t\t\t不问ciaga (不问别离)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:43'}
# {'rank': '155', 'singer': ' Mr.16罗隽永、Simyee陈芯怡\n', 'song': '\n\t\t\t\t\t\t\t\t\t不需要挽留(Move On)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:14'}
# {'rank': '156', 'singer': ' 周深\n', 'song': '\n\t\t\t\t\t\t\t\t\t若梦\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:04'}
# {'rank': '157', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\tWhere Did U Go\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '158', 'singer': ' A', 'song': '\n\t\t\t\t\t\t\t\t\t给我一个理由忘记\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:45'}
# {'rank': '159', 'singer': ' 尹昔眠\n', 'song': '\n\t\t\t\t\t\t\t\t\t斗兽场\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:23'}
# {'rank': '160', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t说好的幸福呢\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:16'}
# {'rank': '161', 'singer': ' 郭顶\n', 'song': '\n\t\t\t\t\t\t\t\t\t我们俩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:13'}
# {'rank': '162', 'singer': ' 李泽轩\n', 'song': '\n\t\t\t\t\t\t\t\t\t心里面的光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:15'}
# {'rank': '163', 'singer': ' Dia\n', 'song': '\n\t\t\t\t\t\t\t\t\t안녕 Goodbye\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:01'}
# {'rank': '164', 'singer': ' Ni/Co\n', 'song': '\n\t\t\t\t\t\t\t\t\tBleeding Love\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:32'}
# {'rank': '165', 'singer': ' 刘阳阳\n', 'song': '\n\t\t\t\t\t\t\t\t\t有苦不声张\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:53'}
# {'rank': '166', 'singer': ' en\n', 'song': '\n\t\t\t\t\t\t\t\t\t如果爱忘了\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:33'}
# {'rank': '167', 'singer': ' 戚薇\n', 'song': '\n\t\t\t\t\t\t\t\t\t如果爱忘了\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '168', 'singer': ' 陈奕迅\n', 'song': '\n\t\t\t\t\t\t\t\t\t十年\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:25'}
# {'rank': '169', 'singer': ' 小乐哥（王唯乐）\n', 'song': '\n\t\t\t\t\t\t\t\t\t慢慢\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:57'}
# {'rank': '170', 'singer': ' 卢旺达青年\n', 'song': '\n\t\t\t\t\t\t\t\t\t为你动了情又死了心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:36'}
# {'rank': '171', 'singer': ' Glichery\n', 'song': '\n\t\t\t\t\t\t\t\t\tSea Of Problems (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '1:50'}
# {'rank': '172', 'singer': ' 五月天\n', 'song': '\n\t\t\t\t\t\t\t\t\t后来的我们\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:46'}
# {'rank': '173', 'singer': ' 崔子格\n', 'song': '\n\t\t\t\t\t\t\t\t\t卜卦\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:36'}
# {'rank': '174', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t我落泪情绪零碎\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '175', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t蒲公英的约定\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:07'}
# {'rank': '176', 'singer': ' 金润吉\n', 'song': '\n\t\t\t\t\t\t\t\t\t迟来的爱 (新版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:25'}
# {'rank': '177', 'singer': ' 蓝心羽\n', 'song': '\n\t\t\t\t\t\t\t\t\t寂寞烟火\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:12'}
# {'rank': '178', 'singer': ' 유다연\n', 'song': '\n\t\t\t\t\t\t\t\t\tdown down down\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:16'}
# {'rank': '179', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t不潮不用花钱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:53'}
# {'rank': '180', 'singer': ' 澤野弘之\n', 'song': '\n\t\t\t\t\t\t\t\t\tCall of Silence\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:58'}
# {'rank': '181', 'singer': ' BEYOND\n', 'song': '\n\t\t\t\t\t\t\t\t\t灰色轨迹\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:27'}
# {'rank': '182', 'singer': ' 一颗狼星\n', 'song': '\n\t\t\t\t\t\t\t\t\t星月原野\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:56'}
# {'rank': '183', 'singer': ' 王以太、刘至佳\n', 'song': '\n\t\t\t\t\t\t\t\t\t危险派对\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:00'}
# {'rank': '184', 'singer': ' Ailee\n', 'song': '\n\t\t\t\t\t\t\t\t\tHEAVEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:31'}
# {'rank': '185', 'singer': ' 戴羽彤\n', 'song': '\n\t\t\t\t\t\t\t\t\t希望你被这个世界爱着\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '186', 'singer': ' Mike Candys\n', 'song': '\n\t\t\t\t\t\t\t\t\tBaby\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:19'}
# {'rank': '187', 'singer': ' 田馥甄\n', 'song': '\n\t\t\t\t\t\t\t\t\t你就不要想起我\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:42'}
# {'rank': '188', 'singer': ' BY2\n', 'song': '\n\t\t\t\t\t\t\t\t\t我知道\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '189', 'singer': ' 汪苏泷\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱丫爱丫 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:47'}
# {'rank': '190', 'singer': ' 张碧晨、王赫野\n', 'song': '\n\t\t\t\t\t\t\t\t\t字字句句 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:52'}
# {'rank': '191', 'singer': ' 王蓝茵\n', 'song': '\n\t\t\t\t\t\t\t\t\t恶作剧\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:46'}
# {'rank': '192', 'singer': ' 张杰、HOYO', 'song': '\n\t\t\t\t\t\t\t\t\t不眠之夜\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:18'}
# {'rank': '193', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t搁浅\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '194', 'singer': ' 刘若英\n', 'song': '\n\t\t\t\t\t\t\t\t\t后来\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:38'}
# {'rank': '195', 'singer': ' ROKIT BAY\n', 'song': '\n\t\t\t\t\t\t\t\t\tDuu Muutai Hun (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:02'}
# {'rank': '196', 'singer': ' 小霞、海洋Bo\n', 'song': '\n\t\t\t\t\t\t\t\t\t向云端\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:11'}
# {'rank': '197', 'singer': ' 告五人\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱人错过\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:52'}
# {'rank': '198', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t我是如此相信\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:25'}
# {'rank': '199', 'singer': ' Hedley\n', 'song': '\n\t\t\t\t\t\t\t\t\tLose Control (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:46'}
# {'rank': '200', 'singer': ' 赵洋\n', 'song': '\n\t\t\t\t\t\t\t\t\t负我不负她\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '201', 'singer': ' JordanBeats\n', 'song': '\n\t\t\t\t\t\t\t\t\tLevels\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:01'}
# {'rank': '202', 'singer': ' 小京东\n', 'song': '\n\t\t\t\t\t\t\t\t\t兜兜转转\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '203', 'singer': ' 程响\n', 'song': '\n\t\t\t\t\t\t\t\t\t可能\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:38'}
# {'rank': '204', 'singer': ' 周杰伦、张惠妹\n', 'song': '\n\t\t\t\t\t\t\t\t\t不该 (with aMEI)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:51'}
# {'rank': '205', 'singer': ' 告五人\n', 'song': '\n\t\t\t\t\t\t\t\t\t唯一\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:30'}
# {'rank': '206', 'singer': ' Yoari\n', 'song': '\n\t\t\t\t\t\t\t\t\tTrue\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:12'}
# {'rank': '207', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t花海\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:24'}
# {'rank': '208', 'singer': ' 凤凰传奇\n', 'song': '\n\t\t\t\t\t\t\t\t\t奢香夫人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:19'}
# {'rank': '209', 'singer': ' HSHK、VodKe\n', 'song': '\n\t\t\t\t\t\t\t\t\tlll Do lt (PHONK)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:38'}
# {'rank': '210', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t泡沫\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:18'}
# {'rank': '211', 'singer': ' 小凌、徐良\n', 'song': '\n\t\t\t\t\t\t\t\t\t无颜女\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:34'}
# {'rank': '212', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t江南\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:27'}
# {'rank': '213', 'singer': ' 孙燕姿\n', 'song': '\n\t\t\t\t\t\t\t\t\t我怀念的\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:49'}
# {'rank': '214', 'singer': ' 刘明湘\n', 'song': '\n\t\t\t\t\t\t\t\t\t漂洋过海来看你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:58'}
# {'rank': '215', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t稻香\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '216', 'singer': ' 吕口口\n', 'song': '\n\t\t\t\t\t\t\t\t\t希望你被这个世界爱着\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:49'}
# {'rank': '217', 'singer': ' Lulleaux、Kid Princess\n', 'song': '\n\t\t\t\t\t\t\t\t\tEmpty Love\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:50'}
# {'rank': '218', 'singer': ' 岳云鹏\n', 'song': '\n\t\t\t\t\t\t\t\t\t西楼儿女\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '219', 'singer': ' 陈村长\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱怎么了\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '220', 'singer': ' 徐佳莹\n', 'song': '\n\t\t\t\t\t\t\t\t\t一样的月光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:00'}
# {'rank': '221', 'singer': ' Matryoshka\n', 'song': '\n\t\t\t\t\t\t\t\t\tSacred Play Secret Place (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:17'}
# {'rank': '222', 'singer': ' 早晚晚\n', 'song': '\n\t\t\t\t\t\t\t\t\t缘为冰 我把它抱在怀里\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:01'}
# {'rank': '223', 'singer': ' Ice Paper\n', 'song': '\n\t\t\t\t\t\t\t\t\t中间人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:20'}
# {'rank': '224', 'singer': ' 善宇\n', 'song': '\n\t\t\t\t\t\t\t\t\t绝处逢生的花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:42'}
# {'rank': '225', 'singer': ' 侯泽润\n', 'song': '\n\t\t\t\t\t\t\t\t\t我把往事化如烟\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:04'}
# {'rank': '226', 'singer': ' 陈奕迅\n', 'song': '\n\t\t\t\t\t\t\t\t\t富士山下\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:19'}
# {'rank': '227', 'singer': ' 周林枫\n', 'song': '\n\t\t\t\t\t\t\t\t\t忘了\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:00'}
# {'rank': '228', 'singer': ' X.Y.L、覆予、歪歪超\n', 'song': '\n\t\t\t\t\t\t\t\t\t猜不透 (说唱版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:24'}
# {'rank': '229', 'singer': ' 告五人\n', 'song': '\n\t\t\t\t\t\t\t\t\t带我去找夜生活\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:59'}
# {'rank': '230', 'singer': ' 徐良、小凌\n', 'song': '\n\t\t\t\t\t\t\t\t\t坏女孩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:02'}
# {'rank': '231', 'singer': ' XloveSF\n', 'song': '\n\t\t\t\t\t\t\t\t\tTired so Problems\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:05'}
# {'rank': '232', 'singer': ' A', 'song': '\n\t\t\t\t\t\t\t\t\t幸福了 然后呢\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:07'}
# {'rank': '233', 'singer': ' 梁静茹\n', 'song': '\n\t\t\t\t\t\t\t\t\t情歌\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '234', 'singer': ' NUEKI、TOLCHONOV、Glichery\n', 'song': '\n\t\t\t\t\t\t\t\t\tTIRED OF PROBLEMS (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '1:49'}
# {'rank': '235', 'singer': ' 张昊晴\n', 'song': '\n\t\t\t\t\t\t\t\t\t最后一页\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '236', 'singer': ' 金新菲\n', 'song': '\n\t\t\t\t\t\t\t\t\t沉溺 (韩语版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:13'}
# {'rank': '237', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t再见\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:26'}
# {'rank': '238', 'singer': ' 阿YueYue、歪歪超\n', 'song': '\n\t\t\t\t\t\t\t\t\t身骑白马 (说唱版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:11'}
# {'rank': '239', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t美人鱼\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:14'}
# {'rank': '240', 'singer': ' 韩安旭\n', 'song': '\n\t\t\t\t\t\t\t\t\t多幸运\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '241', 'singer': ' A', 'song': '\n\t\t\t\t\t\t\t\t\t天若有情\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '242', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t明明就\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '243', 'singer': ' Ari Abdul\n', 'song': '\n\t\t\t\t\t\t\t\t\tBABYDOLL (Speed) (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:36'}
# {'rank': '244', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t修炼爱情\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:47'}
# {'rank': '245', 'singer': ' 古巨基\n', 'song': '\n\t\t\t\t\t\t\t\t\t匆匆那年 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:34'}
# {'rank': '246', 'singer': ' 龙梅子、王强\n', 'song': '\n\t\t\t\t\t\t\t\t\t你把爱情给了谁\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:55'}
# {'rank': '247', 'singer': ' 周传雄\n', 'song': '\n\t\t\t\t\t\t\t\t\t冬天的秘密\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:32'}
# {'rank': '248', 'singer': ' 张碧晨\n', 'song': '\n\t\t\t\t\t\t\t\t\t年轮\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:34'}
# {'rank': '249', 'singer': ' 梁静茹\n', 'song': '\n\t\t\t\t\t\t\t\t\t会呼吸的痛\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:33'}
# {'rank': '250', 'singer': ' 林三七\n', 'song': '\n\t\t\t\t\t\t\t\t\t你往前走不要回头 (你总要学会往前走)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:07'}
# {'rank': '251', 'singer': ' 谢安琪\n', 'song': '\n\t\t\t\t\t\t\t\t\t喜帖街\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:31'}
# {'rank': '252', 'singer': ' 耳朵便利店\n', 'song': '\n\t\t\t\t\t\t\t\t\t乌鸦说情话铁树开了花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:22'}
# {'rank': '253', 'singer': ' 王樾安\n', 'song': '\n\t\t\t\t\t\t\t\t\t会开花的云\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:31'}
# {'rank': '254', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t半岛铁盒\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:19'}
# {'rank': '255', 'singer': ' Ice Paper\n', 'song': '\n\t\t\t\t\t\t\t\t\t心如止水\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:05'}
# {'rank': '256', 'singer': ' 陈韵若、陈每文\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱的回归线\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '257', 'singer': ' 王力宏\n', 'song': '\n\t\t\t\t\t\t\t\t\t我们的歌\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:07'}
# {'rank': '258', 'singer': ' 王力宏\n', 'song': '\n\t\t\t\t\t\t\t\t\t你不知道的事\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:38'}
# {'rank': '259', 'singer': ' 云朵\n', 'song': '\n\t\t\t\t\t\t\t\t\t化风行万里\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:07'}
# {'rank': '260', 'singer': ' 韦礼安\n', 'song': '\n\t\t\t\t\t\t\t\t\t女孩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:06'}
# {'rank': '261', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t借口\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '262', 'singer': ' 银临、Aki阿杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t牵丝戏\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:59'}
# {'rank': '263', 'singer': ' 陶喆\n', 'song': '\n\t\t\t\t\t\t\t\t\t天天\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:15'}
# {'rank': '264', 'singer': ' 黄绮珊、希林娜依高\n', 'song': '\n\t\t\t\t\t\t\t\t\t是妈妈是女儿\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '6:15'}
# {'rank': '265', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t可惜没如果\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:58'}
# {'rank': '266', 'singer': ' 曾至锋\n', 'song': '\n\t\t\t\t\t\t\t\t\t谁\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:17'}
# {'rank': '267', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t戒烟\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:53'}
# {'rank': '268', 'singer': ' Fatrik\n', 'song': '\n\t\t\t\t\t\t\t\t\tFainted Priest\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:41'}
# {'rank': '269', 'singer': ' 卓沅\n', 'song': '\n\t\t\t\t\t\t\t\t\t意想不到\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:52'}
# {'rank': '270', 'singer': ' Tăng Duy Tân、BAE\n', 'song': '\n\t\t\t\t\t\t\t\t\tDạ Vũ (夜舞)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:22'}
# {'rank': '271', 'singer': ' 颜人中\n', 'song': '\n\t\t\t\t\t\t\t\t\t我只能离开 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:06'}
# {'rank': '272', 'singer': ' 张碧晨\n', 'song': '\n\t\t\t\t\t\t\t\t\t笼\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:40'}
# {'rank': '273', 'singer': ' AGA\n', 'song': '\n\t\t\t\t\t\t\t\t\t孤雏\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:53'}
# {'rank': '274', 'singer': ' 陈奕迅\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱情转移\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '275', 'singer': ' 曲婉婷\n', 'song': '\n\t\t\t\t\t\t\t\t\t我的歌声里\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:36'}
# {'rank': '276', 'singer': ' Maroon 5、Wiz Khalifa\n', 'song': '\n\t\t\t\t\t\t\t\t\tPayphone (Explicit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:52'}
# {'rank': '277', 'singer': ' 孙燕姿\n', 'song': '\n\t\t\t\t\t\t\t\t\t遇见\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '278', 'singer': ' 云汐\n', 'song': '\n\t\t\t\t\t\t\t\t\t身骑白马\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:21'}
# {'rank': '279', 'singer': ' 陈奕迅\n', 'song': '\n\t\t\t\t\t\t\t\t\t淘汰\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:45'}
# {'rank': '280', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t最长的电影\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:55'}
# {'rank': '281', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t达尔文\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:06'}
# {'rank': '282', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t夜曲\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:46'}
# {'rank': '283', 'singer': ' 金贵晟\n', 'song': '\n\t\t\t\t\t\t\t\t\t虹之间\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:06'}
# {'rank': '284', 'singer': ' 羊羊\n', 'song': '\n\t\t\t\t\t\t\t\t\t用情\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:34'}
# {'rank': '285', 'singer': ' 任素汐\n', 'song': '\n\t\t\t\t\t\t\t\t\t王招君 (你看你拉住我的模样)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:15'}
# {'rank': '286', 'singer': ' 曾沛慈\n', 'song': '\n\t\t\t\t\t\t\t\t\t够爱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:51'}
# {'rank': '287', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t枫\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:35'}
# {'rank': '288', 'singer': ' 伯爵Johnny、唐伯虎Annie\n', 'song': '\n\t\t\t\t\t\t\t\t\t西厢寻他\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '289', 'singer': ' 松紧先生（李宗锦）\n', 'song': '\n\t\t\t\t\t\t\t\t\t你走 (Demo)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:04'}
# {'rank': '290', 'singer': ' 张韶涵\n', 'song': '\n\t\t\t\t\t\t\t\t\t隐形的翅膀\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:44'}
# {'rank': '291', 'singer': ' 薛之谦\n', 'song': '\n\t\t\t\t\t\t\t\t\t演员\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:21'}
# {'rank': '292', 'singer': ' 郁可唯\n', 'song': '\n\t\t\t\t\t\t\t\t\t去有风的地方\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:51'}
# {'rank': '293', 'singer': ' 张靓颖\n', 'song': '\n\t\t\t\t\t\t\t\t\t画心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '7:12'}
# {'rank': '294', 'singer': ' Dion Timmer、The Arcturians\n', 'song': '\n\t\t\t\t\t\t\t\t\tThe Best Of Me\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:33'}
# {'rank': '295', 'singer': ' 王一一\n', 'song': '\n\t\t\t\t\t\t\t\t\t誓言掺了假\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:27'}
# {'rank': '296', 'singer': ' 李常超（Lao乾妈）\n', 'song': '\n\t\t\t\t\t\t\t\t\t盗墓笔记·十年人间\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:37'}
# {'rank': '297', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t开不了口\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:45'}
# {'rank': '298', 'singer': ' 单依纯\n', 'song': '\n\t\t\t\t\t\t\t\t\t永不失联的爱 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:23'}
# {'rank': '299', 'singer': ' 阿悄\n', 'song': '\n\t\t\t\t\t\t\t\t\t在深秋\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:54'}
# {'rank': '300', 'singer': ' 音阙诗听\n', 'song': '\n\t\t\t\t\t\t\t\t\t红昭愿\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:53'}
# {'rank': '301', 'singer': ' 烟(许佳豪)\n', 'song': '\n\t\t\t\t\t\t\t\t\t再见我的女孩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:19'}
# {'rank': '302', 'singer': ' 温奕心\n', 'song': '\n\t\t\t\t\t\t\t\t\t一路生花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:16'}
# {'rank': '303', 'singer': ' Bôa\n', 'song': '\n\t\t\t\t\t\t\t\t\tDUVET\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:23'}
# {'rank': '304', 'singer': ' 胡彦斌\n', 'song': '\n\t\t\t\t\t\t\t\t\t你要的全拿走\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:59'}
# {'rank': '305', 'singer': ' 郑鱼\n', 'song': '\n\t\t\t\t\t\t\t\t\t荒\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '306', 'singer': ' 板洋\n', 'song': '\n\t\t\t\t\t\t\t\t\t每当我\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:21'}
# {'rank': '307', 'singer': ' en\n', 'song': '\n\t\t\t\t\t\t\t\t\t给我一个理由忘记(那么爱我的你)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:41'}
# {'rank': '308', 'singer': ' 秦海清\n', 'song': '\n\t\t\t\t\t\t\t\t\t诛心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:50'}
# {'rank': '309', 'singer': ' 张信哲\n', 'song': '\n\t\t\t\t\t\t\t\t\t别怕我伤心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:46'}
# {'rank': '310', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t写不完的温柔\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:58'}
# {'rank': '311', 'singer': ' 陆虎\n', 'song': '\n\t\t\t\t\t\t\t\t\t像你这样的朋友\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:05'}
# {'rank': '312', 'singer': ' Zealot周星星\n', 'song': '\n\t\t\t\t\t\t\t\t\t毒药\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:35'}
# {'rank': '313', 'singer': ' MYNAME\n', 'song': "\n\t\t\t\t\t\t\t\t\tBaby I'm Sorry\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ", 'time': '3:42'}
# {'rank': '314', 'singer': ' EXO\n', 'song': "\n\t\t\t\t\t\t\t\t\tBaby, Don't Cry (인어의 눈물)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ", 'time': '3:55'}
# {'rank': '315', 'singer': ' 郑中基\n', 'song': '\n\t\t\t\t\t\t\t\t\t无赖\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:03'}
# {'rank': '316', 'singer': ' 白挺\n', 'song': '\n\t\t\t\t\t\t\t\t\t你从未离去\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '317', 'singer': ' 程今\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱是无畏的冒险\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '318', 'singer': ' Bebe Rexha\n', 'song': '\n\t\t\t\t\t\t\t\t\tFerrari\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:32'}
# {'rank': '319', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t桃花诺\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:39'}
# {'rank': '320', 'singer': ' 别问是海波\n', 'song': '\n\t\t\t\t\t\t\t\t\t凌晨三点的海\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:09'}
# {'rank': '321', 'singer': ' 陈泫孝（大泫）\n', 'song': '\n\t\t\t\t\t\t\t\t\t静悄悄\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:05'}
# {'rank': '322', 'singer': ' Madnap、Pauline Herr\n', 'song': '\n\t\t\t\t\t\t\t\t\tSlow Down\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:23'}
# {'rank': '323', 'singer': ' 萧亚轩\n', 'song': '\n\t\t\t\t\t\t\t\t\t遗失的心跳\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:36'}
# {'rank': '324', 'singer': ' 陈绮贞\n', 'song': '\n\t\t\t\t\t\t\t\t\t太聪明\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:22'}
# {'rank': '325', 'singer': ' aespa\n', 'song': '\n\t\t\t\t\t\t\t\t\tDrama\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:35'}
# {'rank': '326', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\tAlways Online\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:45'}
# {'rank': '327', 'singer': ' 王杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t我是真的爱上你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:02'}
# {'rank': '328', 'singer': ' 7paste\n', 'song': '\n\t\t\t\t\t\t\t\t\t还是会想你 (emo版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:34'}
# {'rank': '329', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t裂缝中的阳光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:48'}
# {'rank': '330', 'singer': ' Zyboy忠宇\n', 'song': '\n\t\t\t\t\t\t\t\t\t妈妈的话\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:50'}
# {'rank': '331', 'singer': ' 张碧晨、Lil Ghost小鬼\n', 'song': '\n\t\t\t\t\t\t\t\t\t指纹 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:25'}
# {'rank': '332', 'singer': ' J.Sheon\n', 'song': '\n\t\t\t\t\t\t\t\t\t别问很可怕\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '333', 'singer': ' 张杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t他不懂\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:51'}
# {'rank': '334', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t唯一\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:13'}
# {'rank': '335', 'singer': ' 颜人中\n', 'song': '\n\t\t\t\t\t\t\t\t\t慢慢\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '336', 'singer': ' Tungevaag、Raaban、Richard Smitt\n', 'song': '\n\t\t\t\t\t\t\t\t\tAll For Love\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:00'}
# {'rank': '337', 'singer': ' 柯柯柯啊\n', 'song': '\n\t\t\t\t\t\t\t\t\t姑娘在远方\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:22'}
# {'rank': '338', 'singer': ' DP龙猪、Swei水、Rays陈袁\n', 'song': '\n\t\t\t\t\t\t\t\t\t风吹一夏\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '339', 'singer': ' Yumekiii\n', 'song': '\n\t\t\t\t\t\t\t\t\tCall of Silence (1.1X超燃版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:02'}
# {'rank': '340', 'singer': ' 陶喆、卢广仲\n', 'song': '\n\t\t\t\t\t\t\t\t\t那个女孩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:27'}
# {'rank': '341', 'singer': ' h3R3\n', 'song': '\n\t\t\t\t\t\t\t\t\t先说谎的人\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:48'}
# {'rank': '342', 'singer': ' 周传雄\n', 'song': '\n\t\t\t\t\t\t\t\t\t黄昏\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:43'}
# {'rank': '343', 'singer': ' 小灿\n', 'song': '\n\t\t\t\t\t\t\t\t\t你总要学会往前走 (男版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:21'}
# {'rank': '344', 'singer': ' 朴树\n', 'song': '\n\t\t\t\t\t\t\t\t\t平凡之路\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:01'}
# {'rank': '345', 'singer': ' Kelly Clarkson\n', 'song': "\n\t\t\t\t\t\t\t\t\tStronger (What Doesn't Kill You)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ", 'time': '3:41'}
# {'rank': '346', 'singer': ' 薛之谦\n', 'song': '\n\t\t\t\t\t\t\t\t\t怪咖\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '347', 'singer': ' 尹昔眠\n', 'song': '\n\t\t\t\t\t\t\t\t\t三拜红尘凉\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '348', 'singer': ' 7paste、live_nine\n', 'song': '\n\t\t\t\t\t\t\t\t\t罗生门 (follow)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:51'}
# {'rank': '349', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t年少有为\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:39'}
# {'rank': '350', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t我的秘密\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:12'}
# {'rank': '351', 'singer': ' 青鸟飞鱼\n', 'song': '\n\t\t\t\t\t\t\t\t\t此生不换\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:27'}
# {'rank': '352', 'singer': ' 徐誉滕\n', 'song': '\n\t\t\t\t\t\t\t\t\t做我老婆好不好\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:27'}
# {'rank': '353', 'singer': ' 陈雪凝\n', 'song': '\n\t\t\t\t\t\t\t\t\t绿色\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:29'}
# {'rank': '354', 'singer': ' 梁博\n', 'song': '\n\t\t\t\t\t\t\t\t\t男孩 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:29'}
# {'rank': '355', 'singer': ' RE', 'song': '\n\t\t\t\t\t\t\t\t\t如果我们在余生相遇 (变调版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '356', 'singer': ' Whitney Houston\n', 'song': '\n\t\t\t\t\t\t\t\t\tCall You Tonight\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '357', 'singer': ' 王若琳\n', 'song': '\n\t\t\t\t\t\t\t\t\t有你的快乐\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:17'}
# {'rank': '358', 'singer': ' Olly Murs\n', 'song': '\n\t\t\t\t\t\t\t\t\tThat Girl\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:56'}
# {'rank': '359', 'singer': ' 队长、鹿晗\n', 'song': '\n\t\t\t\t\t\t\t\t\t影子\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:28'}
# {'rank': '360', 'singer': ' 赵英俊\n', 'song': '\n\t\t\t\t\t\t\t\t\t送你一朵小红花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:52'}
# {'rank': '361', 'singer': ' Vnriet\n', 'song': '\n\t\t\t\t\t\t\t\t\tSuffocating (Deep House Edit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:14'}
# {'rank': '362', 'singer': ' 雨帆\n', 'song': '\n\t\t\t\t\t\t\t\t\t荒 (我曾爱过一个人竹笛纯享版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:55'}
# {'rank': '363', 'singer': ' 郭顶\n', 'song': '\n\t\t\t\t\t\t\t\t\t水星记\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:25'}
# ...
# {'rank': '383', 'singer': ' 刘德华\n', 'song': '\n\t\t\t\t\t\t\t\t\t道理都懂\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:03'}
# {'rank': '384', 'singer': ' 许巍\n', 'song': '\n\t\t\t\t\t\t\t\t\t曾经的你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:21'}
# {'rank': '385', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t背对背拥抱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '386', 'singer': ' T3nzu\n', 'song': '\n\t\t\t\t\t\t\t\t\tDrive Forever (Slowed)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:40'}
# {'rank': '387', 'singer': ' 李荣浩\n', 'song': '\n\t\t\t\t\t\t\t\t\t模特\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:06'}
# {'rank': '388', 'singer': ' 花粥、王胜娚\n', 'song': '\n\t\t\t\t\t\t\t\t\t出山\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:20'}
# {'rank': '389', 'singer': ' 筷子兄弟\n', 'song': '\n\t\t\t\t\t\t\t\t\t老男孩\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:00'}
# {'rank': '390', 'singer': ' Rin7\n', 'song': '\n\t\t\t\t\t\t\t\t\tEXTASY (迈巴赫版)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:14'}
# {'rank': '391', 'singer': ' Taylor Swift\n', 'song': '\n\t\t\t\t\t\t\t\t\tWelcome To New York\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:32'}
# {'rank': '392', 'singer': ' 赵雷\n', 'song': '\n\t\t\t\t\t\t\t\t\t程艾影\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:00'}
# {'rank': '393', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t说了再见\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:42'}
# {'rank': '394', 'singer': ' 梦然\n', 'song': '\n\t\t\t\t\t\t\t\t\t是你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '395', 'singer': ' 于果\n', 'song': '\n\t\t\t\t\t\t\t\t\t侧脸\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:37'}
# {'rank': '396', 'singer': ' 岛管\n', 'song': '\n\t\t\t\t\t\t\t\t\t突然爱上你（我就在此刻突然爱上你）\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:03'}
# {'rank': '397', 'singer': ' Henry Young、Ashley Alisha\n', 'song': '\n\t\t\t\t\t\t\t\t\tOne More Last Time\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:09'}
# {'rank': '398', 'singer': ' 刘鹏\n', 'song': '\n\t\t\t\t\t\t\t\t\t太阳 (你看着我眼睛)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:46'}
# {'rank': '399', 'singer': ' Charlie Puth、Selena Gomez\n', 'song': "\n\t\t\t\t\t\t\t\t\tWe Don't Talk Anymore\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ", 'time': '3:37'}
# {'rank': '400', 'singer': ' RE', 'song': '\n\t\t\t\t\t\t\t\t\t肯定\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:02'}
# {'rank': '401', 'singer': ' akiaura、LONOWN、STM\n', 'song': '\n\t\t\t\t\t\t\t\t\tSleepwalker (Slowed)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:18'}
# {'rank': '402', 'singer': ' Tanir & Tyomcha\n', 'song': '\n\t\t\t\t\t\t\t\t\tDa Da Da\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '403', 'singer': ' Taylor Swift\n', 'song': '\n\t\t\t\t\t\t\t\t\tBlank Space\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:51'}
# {'rank': '404', 'singer': ' 呆呆破\n', 'song': '\n\t\t\t\t\t\t\t\t\t雪藏\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '405', 'singer': ' 南拳妈妈\n', 'song': '\n\t\t\t\t\t\t\t\t\t下雨天\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:13'}
# {'rank': '406', 'singer': ' 薛之谦\n', 'song': '\n\t\t\t\t\t\t\t\t\t天外来物\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '407', 'singer': ' 阿YueYue、戾格\n', 'song': '\n\t\t\t\t\t\t\t\t\t沈园外\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '408', 'singer': ' 付豪\n', 'song': '\n\t\t\t\t\t\t\t\t\t他真的对你好吗\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:17'}
# {'rank': '409', 'singer': ' Trouble Maker\n', 'song': '\n\t\t\t\t\t\t\t\t\tTrouble Maker\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:39'}
# {'rank': '410', 'singer': ' 陈慧娴\n', 'song': '\n\t\t\t\t\t\t\t\t\t千千阕歌\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:01'}
# {'rank': '411', 'singer': ' The Weeknd\n', 'song': '\n\t\t\t\t\t\t\t\t\tAfter Hours\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '6:01'}
# {'rank': '412', 'singer': ' cici_\n', 'song': '\n\t\t\t\t\t\t\t\t\t把回忆拼好给你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:24'}
# {'rank': '413', 'singer': ' 任然\n', 'song': '\n\t\t\t\t\t\t\t\t\t疑心病\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:44'}
# {'rank': '414', 'singer': ' 周慧敏\n', 'song': '\n\t\t\t\t\t\t\t\t\t最爱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:25'}
# {'rank': '415', 'singer': ' 就是南方凯\n', 'song': '\n\t\t\t\t\t\t\t\t\t巡光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:29'}
# {'rank': '416', 'singer': ' Reynard Silva\n', 'song': '\n\t\t\t\t\t\t\t\t\tThe Way I Still Love You\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:48'}
# {'rank': '417', 'singer': ' 杨丞琳\n', 'song': '\n\t\t\t\t\t\t\t\t\t匿名的好友\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:22'}
# {'rank': '418', 'singer': ' 郭静\n', 'song': '\n\t\t\t\t\t\t\t\t\t心墙\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:47'}
# {'rank': '419', 'singer': ' 井迪儿\n', 'song': '\n\t\t\t\t\t\t\t\t\t失控\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:15'}
# {'rank': '420', 'singer': ' AGA\n', 'song': '\n\t\t\t\t\t\t\t\t\tWonderful U (Demo Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '421', 'singer': ' 王忻辰、苏星婕\n', 'song': '\n\t\t\t\t\t\t\t\t\t清空\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '422', 'singer': ' KALEO\n', 'song': '\n\t\t\t\t\t\t\t\t\tWay Down We Go\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:39'}
# {'rank': '423', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t爱在西元前\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:54'}
# {'rank': '424', 'singer': ' 光泽\n', 'song': '\n\t\t\t\t\t\t\t\t\t空心\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:39'}
# {'rank': '425', 'singer': ' Lil笑笑\n', 'song': '\n\t\t\t\t\t\t\t\t\t山茶花读不懂白玫瑰\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:19'}
# {'rank': '426', 'singer': ' 王力宏\n', 'song': '\n\t\t\t\t\t\t\t\t\t天地龙鳞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:16'}
# {'rank': '427', 'singer': ' Kastra\n', 'song': '\n\t\t\t\t\t\t\t\t\tFool For You\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:27'}
# {'rank': '428', 'singer': ' 潘玮柏、弦子\n', 'song': '\n\t\t\t\t\t\t\t\t\t不得不爱\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:41'}
# {'rank': '429', 'singer': ' sunkis 宋秉勤\n', 'song': '\n\t\t\t\t\t\t\t\t\ttrust me\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:48'}
# {'rank': '430', 'singer': ' 李玖哲\n', 'song': '\n\t\t\t\t\t\t\t\t\t不只是场梦\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:32'}
# {'rank': '431', 'singer': ' 顾飞飞\n', 'song': '\n\t\t\t\t\t\t\t\t\t予你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:23'}
# {'rank': '432', 'singer': ' 金莎\n', 'song': '\n\t\t\t\t\t\t\t\t\t星月神话\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '433', 'singer': ' 光良\n', 'song': '\n\t\t\t\t\t\t\t\t\t童话\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:05'}
# {'rank': '434', 'singer': ' 陶喆、蔡依林\n', 'song': '\n\t\t\t\t\t\t\t\t\t今天你要嫁给我\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:32'}
# {'rank': '435', 'singer': ' HLHS\n', 'song': '\n\t\t\t\t\t\t\t\t\tlll Do lt (Reverb Slowed)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:13'}
# {'rank': '436', 'singer': ' 刘若英\n', 'song': '\n\t\t\t\t\t\t\t\t\t当爱在靠近\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '437', 'singer': ' KARTASHOW、Мари Краймбрери\n', 'song': '\n\t\t\t\t\t\t\t\t\tЗолото (黄金)(Rakurs & Ramirez Remix)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:11'}
# {'rank': '438', 'singer': ' やまだ豊\n', 'song': '\n\t\t\t\t\t\t\t\t\tやわらかな光 (柔和之光)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '6:03'}
# {'rank': '439', 'singer': ' 鱼闪闪BLING\n', 'song': '\n\t\t\t\t\t\t\t\t\t离别开出花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:42'}
# {'rank': '440', 'singer': ' 沈梦溪\n', 'song': '\n\t\t\t\t\t\t\t\t\t妈妈的话\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:41'}
# {'rank': '441', 'singer': ' Ayo97、周思涵\n', 'song': '\n\t\t\t\t\t\t\t\t\t感谢你曾来过\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:10'}
# {'rank': '442', 'singer': ' Tank\n', 'song': '\n\t\t\t\t\t\t\t\t\t三国恋\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:06'}
# {'rank': '443', 'singer': ' Ashley Alisha\n', 'song': '\n\t\t\t\t\t\t\t\t\tClues\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:15'}
# {'rank': '444', 'singer': ' Alan Walker\n', 'song': '\n\t\t\t\t\t\t\t\t\tFaded\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:32'}
# {'rank': '445', 'singer': ' 任夏\n', 'song': '\n\t\t\t\t\t\t\t\t\t别爱太满别睡太晚\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:04'}
# {'rank': '446', 'singer': ' 许嵩、何曼婷\n', 'song': '\n\t\t\t\t\t\t\t\t\t素颜\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:58'}
# {'rank': '447', 'singer': ' 蓝心羽\n', 'song': '\n\t\t\t\t\t\t\t\t\t阿拉斯加海湾\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:57'}
# {'rank': '448', 'singer': ' 周杰伦\n', 'song': '\n\t\t\t\t\t\t\t\t\t等你下课 (with 杨瑞代)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:30'}
# {'rank': '449', 'singer': ' 王心凌\n', 'song': '\n\t\t\t\t\t\t\t\t\t黄昏晓\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:55'}
# {'rank': '450', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t裹着心的光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:33'}
# {'rank': '451', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t11\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:48'}
# {'rank': '452', 'singer': ' IVE\n', 'song': '\n\t\t\t\t\t\t\t\t\tBaddie\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:34'}
# {'rank': '453', 'singer': ' 原来是歪\n', 'song': '\n\t\t\t\t\t\t\t\t\t心跳的证明\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:26'}
# {'rank': '454', 'singer': ' 尹美莱、Tiger JK、Bizzy\n', 'song': '\n\t\t\t\t\t\t\t\t\tAngel\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:15'}
# {'rank': '455', 'singer': ' VØJ、Narvent\n', 'song': '\n\t\t\t\t\t\t\t\t\tMemory Reboot (Slowed)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:56'}
# {'rank': '456', 'singer': ' 陈柏宇\n', 'song': '\n\t\t\t\t\t\t\t\t\t你瞒我瞒\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:57'}
# {'rank': '457', 'singer': ' 队长\n', 'song': '\n\t\t\t\t\t\t\t\t\t哪里都是你\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:42'}
# {'rank': '458', 'singer': ' EXO\n', 'song': "\n\t\t\t\t\t\t\t\t\tBaby, Don't Cry (人鱼的眼泪) (Chinese Ver.)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ", 'time': '3:55'}
# {'rank': '459', 'singer': ' 胡彦斌\n', 'song': '\n\t\t\t\t\t\t\t\t\t月光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:39'}
# {'rank': '460', 'singer': ' 周杰伦、Lara梁心颐\n', 'song': '\n\t\t\t\t\t\t\t\t\t珊瑚海\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:15'}
# {'rank': '461', 'singer': ' 沈诚诚\n', 'song': '\n\t\t\t\t\t\t\t\t\t与我无关\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '462', 'singer': ' Walk Off the Earth、Luminati Suns\n', 'song': '\n\t\t\t\t\t\t\t\t\tMy Stupid Heart (Kids Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:48'}
# {'rank': '463', 'singer': ' 1K\n', 'song': '\n\t\t\t\t\t\t\t\t\t就忘了吧\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:23'}
# {'rank': '464', 'singer': ' The Kid LAROI、Justin Bieber\n', 'song': '\n\t\t\t\t\t\t\t\t\tSTAY (Clean)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:21'}
# {'rank': '465', 'singer': ' 阿悄\n', 'song': '\n\t\t\t\t\t\t\t\t\t海海海\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:06'}
# {'rank': '466', 'singer': ' G.E.M. 邓紫棋\n', 'song': '\n\t\t\t\t\t\t\t\t\t光年之外\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:55'}
# {'rank': '467', 'singer': ' 刘烨溦\n', 'song': '\n\t\t\t\t\t\t\t\t\t不如回家喝自来水\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:45'}
# {'rank': '468', 'singer': ' 5 Seconds of Summer\n', 'song': '\n\t\t\t\t\t\t\t\t\tTeeth\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:24'}
# {'rank': '469', 'singer': ' 张靓颖\n', 'song': '\n\t\t\t\t\t\t\t\t\t我们说好的\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:30'}
# {'rank': '470', 'singer': ' 宋盐球\n', 'song': '\n\t\t\t\t\t\t\t\t\t泼天的富贵\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:57'}
# {'rank': '471', 'singer': ' 采风乐坊\n', 'song': '\n\t\t\t\t\t\t\t\t\t蓄勢 ～ GEAR UP ～ (蓄势~准备就绪~)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:22'}
# {'rank': '472', 'singer': ' Mr.16罗隽永\n', 'song': '\n\t\t\t\t\t\t\t\t\t青花瓷\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:22'}
# {'rank': '473', 'singer': ' hanji\n', 'song': '\n\t\t\t\t\t\t\t\t\tBurn Me Down\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:31'}
# {'rank': '474', 'singer': ' 林俊杰\n', 'song': '\n\t\t\t\t\t\t\t\t\t那些你很冒险的梦\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:04'}
# {'rank': '475', 'singer': ' 弦子、小乐哥（王唯乐）\n', 'song': '\n\t\t\t\t\t\t\t\t\t不甘 (Live)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '476', 'singer': ' 李宇春\n', 'song': '\n\t\t\t\t\t\t\t\t\t下个，路口，见\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '477', 'singer': ' The Weeknd\n', 'song': '\n\t\t\t\t\t\t\t\t\tDie For You\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:20'}
# {'rank': '478', 'singer': ' 當山みれい\n', 'song': '\n\t\t\t\t\t\t\t\t\t願い〜あの頃のキミへ〜 (祈愿～致那个时候的你～)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:40'}
# {'rank': '479', 'singer': ' 林三七\n', 'song': '\n\t\t\t\t\t\t\t\t\t栀子花的约定\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:55'}
# {'rank': '480', 'singer': ' (G)I', 'song': '\n\t\t\t\t\t\t\t\t\t퀸카 (Queencard)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:41'}
# {'rank': '481', 'singer': ' 许巍\n', 'song': '\n\t\t\t\t\t\t\t\t\t蓝莲花\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:30'}
# {'rank': '482', 'singer': ' en\n', 'song': '\n\t\t\t\t\t\t\t\t\t你是我的风景\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:43'}
# {'rank': '483', 'singer': ' Creeds\n', 'song': '\n\t\t\t\t\t\t\t\t\tPush Up (Main Edit)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:19'}
# {'rank': '484', 'singer': ' 浮生梦\n', 'song': '\n\t\t\t\t\t\t\t\t\t星月落\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '485', 'singer': ' JVKE\n', 'song': '\n\t\t\t\t\t\t\t\t\tgolden hour\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:29'}
# {'rank': '486', 'singer': ' 王冕\n', 'song': '\n\t\t\t\t\t\t\t\t\t勉为其难\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:09'}
# {'rank': '487', 'singer': ' VodKe、HSHK\n', 'song': '\n\t\t\t\t\t\t\t\t\tGIMME (Version)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:08'}
# {'rank': '488', 'singer': ' Rauf & Faik\n', 'song': '\n\t\t\t\t\t\t\t\t\tКолыбельная (摇篮曲)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:53'}
# {'rank': '489', 'singer': ' 丹正母子\n', 'song': '\n\t\t\t\t\t\t\t\t\t乌兰巴托的夜\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:11'}
# {'rank': '490', 'singer': ' T', 'song': '\n\t\t\t\t\t\t\t\t\tFalling U\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:30'}
# {'rank': '491', 'singer': ' Wilee\n', 'song': '\n\t\t\t\t\t\t\t\t\tNight Drive\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '2:04'}
# {'rank': '492', 'singer': ' 苏星婕\n', 'song': '\n\t\t\t\t\t\t\t\t\t听悲伤的情歌\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '3:18'}
# {'rank': '493', 'singer': ' 陈势安\n', 'song': '\n\t\t\t\t\t\t\t\t\t天后\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:49'}
# {'rank': '494', 'singer': ' 周深\n', 'song': '\n\t\t\t\t\t\t\t\t\t大鱼\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:13'}
# {'rank': '495', 'singer': ' 赵雷\n', 'song': '\n\t\t\t\t\t\t\t\t\t我们的时光\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:30'}
# {'rank': '496', 'singer': ' 黄小琥\n', 'song': '\n\t\t\t\t\t\t\t\t\t没那么简单\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '5:08'}
# {'rank': '497', 'singer': ' 贾玲\n', 'song': '\n\t\t\t\t\t\t\t\t\t一切都来得及\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:56'}
# {'rank': '498', 'singer': ' 李发发\n', 'song': '\n\t\t\t\t\t\t\t\t\t我要的不是雪\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:05'}
# {'rank': '499', 'singer': ' 大欢\n', 'song': '\n\t\t\t\t\t\t\t\t\t化风行万里\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:27'}
# {'rank': '500', 'singer': ' Meg Myers\n', 'song': '\n\t\t\t\t\t\t\t\t\tRunning Up That Hill\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ', 'time': '4:23'}
